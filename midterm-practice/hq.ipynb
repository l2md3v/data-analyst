# %%
from scipy.stats import binom
from scipy.stats import poisson
from scipy.stats import norm
from scipy.stats import t

import matplotlib.pyplot as plt

# %%
norm.cdf(162, 172, 5)
# Out:
# 0.022750131948179195

# %%
norm.cdf(182, 172, 5)
# Out:
# 0.9772498680518208

# %%
norm.cdf(182, 172, 5) - norm.cdf(165, 172, 5)
# Out:
# 0.8964932088180497

# %%
norm.ppf(0.06, 172, 5)
# Out:
# 164.22613202701572

# %%
norm.ppf(1 - 0.09, 172, 5)
# Out:
# 178.70377516845107

# %%
# ve bieu do mo ta phan phoi tren

x = range(150, 200)
y = norm.pdf(x, 172, 5)
plt.plot(x, y)
plt.xlabel("Height")
plt.show()
