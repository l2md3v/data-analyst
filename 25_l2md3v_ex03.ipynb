# %% [markdown]
# # Lab 03 - Bài tập

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## NUMPY
#
# Bạn hãy phát sinh ngẫu nhiên mảng ndarray có tên `arr` gồm 100 phần tử số nguyên có giá trị từ 0..1000. Thực hiện các thao tác sau:

# %%
arr = np.random.randint(0, 1000, 100)
arr
# Out:
# array([832, 668, 555, 455, 426, 361, 552,  19, 579, 820, 405,  11,  91,
#        797, 692, 159, 118, 356,   6,  25, 673, 521, 208, 310, 615, 818,
#        182, 743, 871, 294, 458, 724, 893, 922, 943, 431, 794, 101, 908,
#          3, 805, 444, 379, 665,  71, 302, 580, 516, 471, 226,  84,  96,
#        167, 185, 362, 574, 492,  21, 177, 451, 710, 416, 235,   4, 988,
#        758, 262, 882, 417, 755, 118, 615, 350, 351, 141, 548, 677, 565,
#         88,  81, 199, 133, 421, 607, 571, 150, 988, 501,  31, 509, 567,
#        501,  22, 156,  15,  97, 796,   6, 228,  67])

# %% [markdown]
# ### 1. Hiển thị các phần tử thỏa yêu cầu dưới đây
#
# - 10 phần tử đầu tiên
# - 5 phần tử cuối cùng
# - Các phần tử thỏa mãn điều kiện chia hết cho 5 và lớn hơn 100

# %%
arr[:10]
# Out:
# array([832, 668, 555, 455, 426, 361, 552,  19, 579, 820])

# %%
arr[-5:]
# Out:
# array([ 97, 796,   6, 228,  67])

# %%
arr[(arr % 5 == 0) & (arr > 100)]
# Out:
# array([555, 455, 820, 405, 310, 615, 805, 665, 580, 185, 710, 235, 755,
#        615, 350, 565, 150])

# %% [markdown]
# ### 2. Cho biết mảng trên có bao nhiêu phần tử có giá trị nhỏ hơn 100. Hiển thị các phần tử đó

# %%
np.count_nonzero(arr < 100), arr[arr < 100]
# Out:
# (19,
#  array([19, 11, 91,  6, 25,  3, 71, 84, 96, 21,  4, 88, 81, 31, 22, 15, 97,
#          6, 67]))

# %% [markdown]
# ### 3. Thực hiện thống kê:
#
# - Tính tổng mảng
# - Tìm giá trị trung bình
# - Tìm giá trị trung vị
# - Tìm Q1, Q2, Q3
# - Tìm phân vị 20 (percentile 20)

# %%
arr.sum()
# Out:
# 41933

# %%
arr.mean()
# Out:
# 419.33

# %%
np.median(arr)
# Out:
# 423.5

# %%
np.percentile(arr, [25, 50, 75])
# Out:
# array([154.5, 423.5, 627.5])

# %%
np.percentile(arr, 20)
# Out:
# 114.60000000000001

# %% [markdown]
# ### 4. Thực hiện việc chọn ngẫu nhiên (không thay thế) 10 phần tử từ mảng trên 5 lần. Hiển thị kết quả lựa chọn mỗi lần

# %%
for _ in range(5):
    print(arr[np.random.choice(arr.shape[0], 10, replace=False)])
# Out:
# [521 665 677 871  71   3 988 471   4  96]
# [421 294 922 492 552  91 908 182 310 509]
# [501 692 665 509 615 567 677 820 362 228]
# [118 615 416  88 156 796  11 101 797 141]
# [379   6 182 521 943  67 361 565 118 882]

# %% [markdown]
# ### 5. Tìm phần tử xuất hiện nhiều nhất trong mảng

# %%
np.bincount(arr).argmax()
# Out:
# 6

# %% [markdown]
# ---

# %% [markdown]
# ## MATPLOTLIB

# %% [markdown]
# Viết mã để vẽ các đồ thị sau:

# %% [markdown]
# ### Câu 1: Đồ thị đường thẳng

# %%
plt.plot([1, 2, 3], [2, 4, 1])

plt.title("Sample graph!")
plt.xlabel("x - axis")
plt.ylabel("y - axis")
plt.show()

# %% [markdown]
# ### Câu 2: Vẽ hai đường thẳng

# %%
y = [10, 20, 30]

plt.plot(y, [20, 40, 10], "r", label="Line 1")
plt.plot(y, [40, 10, 30], "b", label="Line 2")

plt.title("Do thi hai duong thang")
plt.xlabel("x - axis")
plt.ylabel("y - axis")

plt.legend()
plt.show()

# %% [markdown]
# ### Câu 3: Sử dụng marker

# %%
plt.plot([1, 4, 5, 6, 7], [2, 6, 3, 6, 3], marker="o", mec="red", mfc="orange")

plt.title("Sử dụng marker")
plt.xlabel("x - axis")
plt.ylabel("y - axis")

plt.show()

# %% [markdown]
# ### Câu 4: Định dạng đường thẳng
#
# Phát sinh x là các điểm dữ liệu từ $[0, \pi]$. Bạn hãy vẽ đồ thị $y = sin(x)$ và $y = cos(x)$ như dưới đây.
# Gợi ý: sử dụng hằng số pi và hàm sau:
# - `np.pi` : số $\pi$
# - `np.linspace()`
# - `np.sin()`
# - `np.cos()`

# %%
x = np.linspace(0, 2 * np.pi, 180)

plt.plot(x, np.sin(x), label="sin(x)")
plt.plot(x, np.cos(x), label="cos(x)", ls="--")

plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### Câu 5: Vẽ các đồ thị con

# %%
x = np.linspace(0, 2 * np.pi, 180)

plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x), label="sin(x)")
plt.legend()


plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x), "r", label="cos(x)")
plt.legend()


plt.show()

# %% [markdown]
# ### Câu 6: Vẽ đồ thị cột

# %%
x = np.array(["Java", "Python", "PHP", "JavaScript", "C#", "C++"])
y = np.array([23, 18, 9, 8, 7, 6])

plt.bar(x, y)

plt.title("Muc do pho bien cua cac ngon ngu lap trinh")
plt.xlabel("Programming Langague")
plt.ylabel("Popularity")
plt.show()

# %% [markdown]
# ### Câu  7: Vẽ đồ thị bánh

# %%
data = [24.79, 12.39, 11.27, 10.85, 9.44, 31.27]
labels = ["Python", "PHP", "JavaScript", "C#", "C++", "Java"]

plt.pie(data, labels=labels, autopct="%.2f%%", explode=[0, 0, 0, 0, 0, 0.1])

plt.show()

# %% [markdown]
# ### Câu 8: Vẽ histogram
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ histogram các số ngẫu nhiên trên.

# %%
plt.hist(np.random.normal(size=10000), bins=100)

plt.title("Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Câu 9: Vẽ đồ thị hộp
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ boxplot các số ngẫu nhiên trên.

# %%
plt.boxplot(np.random.normal(size=10000))

plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Câu 10: Kết hợp trên cùng một đồ thị
#
# Sử dụng hàm `np.random.normal(size=10000)` để phát sinh 10000 số ngẫu nghiên thuộc phân phối chuẩn. Vẽ hình thể hiện phân phối như sau:
#
# Hướng dẫn: thêm tham số `vert=False` trong hàm vẽ `boxplot()`

# %%
data = np.random.normal(size=10000)

fig, ax = plt.subplots(2, 1, constrained_layout=True)

ax[0].hist(data, bins=200, rwidth=0.6, color="#800080")
ax[0].set_title("Histogram")
ax[0].set_ylabel("Mật độ")

ax[1].boxplot(data, vert=False)
ax[1].set_title("Boxplot")

fig.suptitle("Đồ thị hàm sin(x) và cos(x)")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## SEABORN

# %% [markdown]
# Seaborn là một thư viện hỗ trợ trực quan hóa được viết dựa trên thư viện `matplotlib`. Trong bài tập này, bạn hãy tự tìm hiểu thư viện `seaborn` và trực quan hóa dữ liệu tiền tip tại một nhà hàng.
#
# Bạn có thể dùng đoạn mã sau để đọc dữ liệu có sẵn trong `seaborn`
#
# ```python
# import seaborn as sns
#
# df = sns.load_dataset("tips")
# df.head()
# ```
# Hoặc bạn có thể đọc dữ liệu chứa trong file `tips.csv` chứa thông tin tiền tip của khách hàng tại một nhà hàng. Dữ liệu có các thông tin sau:
#
# - `total_bill`: tổng hoá đơn (USD)
# - `tip`: tiền tip/ tiền boa (USD)
# - `sex`: giới tính người thanh toán hóa đơn
# - `smoker`: có hút thuốc hay không
# - `day`: ngày trong tuần
# - `time`: thời gian dùng bữa(buổi sáng, buổi trưa, buổi tối)
# - `size`: số lượng người tham gia
#
# Bạn hãy lựa chọn loại đồ thị phù hợp để trả lời những câu hỏi sau:

# %%
df = sns.load_dataset("tips")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### 1. Vẽ đồ thị thể hiện tổng tiền tip theo ngày

# %%
sns.lineplot(data=df, x="day", y="tip")
# Out:
# /home/tiesen/miniconda3/envs/main/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/tiesen/miniconda3/envs/main/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# ### 2. Vẽ đồ thị thể hiện tổng tiền tip theo thời gian dùng bữa (time)

# %%
sns.lineplot(data=df, x="time", y="tip")
# Out:
# /home/tiesen/miniconda3/envs/main/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/tiesen/miniconda3/envs/main/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='time', ylabel='tip'>

# %% [markdown]
# ### 3. Vẽ đồ thị histogram của tổng hoá đơn

# %%
sns.histplot(data=df, x="total_bill", kde=True)
# Out:
# /home/tiesen/miniconda3/envs/main/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ### 4. Vẽ đồ thị boxplot của tổng hoá đơn

# %%
sns.boxenplot(df["total_bill"])
# Out:
# /home/tiesen/miniconda3/envs/main/lib/python3.11/site-packages/seaborn/categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: >

# %% [markdown]
# ### 5. Vẽ đồ thị boxplot so sánh tổng hóa đơn giữa các ngày trong tuần

# %%
sns.boxplot(data=df, x="day", y="total_bill")
# Out:
# /home/tiesen/miniconda3/envs/main/lib/python3.11/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### 6. Vẽ đồ thị để kiểm tra sự liên quan giữa tổng hoá đơn và tiền tip. (`scatter plot`)

# %%
sns.scatterplot(data=df, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ### 7. Tìm hiểu và sử dụng hàm `jointplot` trong seaborn để khảo sát quan hệ giữa hai thuộc tính `total_bill` và `tip`. Theo bạn hai thuộc tính này có tương quan với nhau hay không?

# %%
sns.jointplot(data=df, x="total_bill", y="tip")
# Out:
# /home/tiesen/miniconda3/envs/main/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/tiesen/miniconda3/envs/main/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Hai thuộc tính này tương quan với nhau. `total_bill` càng lớn thì `tip` càng lớn.

# %% [markdown]
# ### 8. Tìm hiểu và sử dụng hàm `pairplot` trong seaborn để trực quan bộ dữ liệu. Theo bạn, trong bộ dữ liệu có những thuộc tính nào liên quan với nhau không?

# %%
sns.pairplot(data=df)
# Out:
# /home/tiesen/miniconda3/envs/main/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/tiesen/miniconda3/envs/main/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/tiesen/miniconda3/envs/main/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Trong bộ dữ liệu có những thuộc tính liên quan với nhau như `total_bill` và `tip`, `total_bill` và `size`, `tip` và `size`.

# %% [markdown]
# ### 9. Vẽ hai đồ thị histogram cạnh nhau để so sánh tổng hóa đơn giữa hai thời gian dùng bữa `Lunch` và `Dinner`

# %%
sns.histplot(data=df, x="time", y="total_bill")
# Out:
# /home/tiesen/miniconda3/envs/main/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/tiesen/miniconda3/envs/main/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='time', ylabel='total_bill'>

# %% [markdown]
# ### 10. Vẽ hai đồ thị boxplot cạnh nhau để so sánh tổng hóa đơn giữa hai thời gian dùng bữa `Lunch` và `Dinner`

# %%
sns.boxenplot(data=df, x="time", y="total_bill")
# Out:
# /home/tiesen/miniconda3/envs/main/lib/python3.11/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /home/tiesen/miniconda3/envs/main/lib/python3.11/site-packages/seaborn/categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /home/tiesen/miniconda3/envs/main/lib/python3.11/site-packages/seaborn/categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='time', ylabel='total_bill'>

# %% [markdown]
# ---
